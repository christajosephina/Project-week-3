# %%
#importing pandas and dataset

# %%
import pandas as pd

# %%
df = pd.read_excel("Donor registration.xlsx")

# %%
#examining the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Background     35 non-null     object
#  1   Time           35 non-null     int64
#  2   Permission     35 non-null     float64
#  3   Partly         35 non-null     float64
#  4   No_permission  35 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
df
# Out:
#      Background  Time  Permission  Partly  No_permission
# 0         Dutch  2014      2546.1   620.4         1289.5
# 1         Dutch  2015      2572.9   639.2         1278.2
# 2         Dutch  2016      2608.4   661.5         1259.5
# 3         Dutch  2017      2622.2   676.5         1350.3
# 4         Dutch  2018      2646.5   698.6         1459.6
# 5         Dutch  2019      2641.7   703.6         1480.9
# 6         Dutch  2020      2692.0   762.6         1729.9
# 7       Western  2014       205.7    46.7          146.2
# 8       Western  2015       208.1    48.0          145.3
# 9       Western  2016       211.5    49.6          143.6
# 10      Western  2017       213.9    50.6          156.8
# 11      Western  2018       217.0    52.0          171.3
# 12      Western  2019       218.1    52.4          176.1
# 13      Western  2020       226.1    56.6          211.3
# 14  Non-western  2014        44.5    19.8          146.6
# 15  Non-western  2015        46.9    21.2          150.6
# 16  Non-western  2016        49.8    22.7          153.1
# 17  Non-western  2017        52.6    23.9          201.2
# 18  Non-western  2018        56.2    25.4          269.4
# 19  Non-western  2019        57.5    25.9          292.5
# 20  Non-western  2020        63.0    29.1          383.8
# 21         1gen  2014        84.1    21.3          159.4
# 22         1gen  2015        86.0    22.1          160.6
# 23         1gen  2016        88.7    23.0          160.2
# 24         1gen  2017        91.7    23.6          191.1
# 25         1gen  2018        94.9    24.3          231.0
# 26         1gen  2019        97.2    24.7          248.3
# 27         1gen  2020       105.4    27.0          317.9
# 28         2gen  2014       166.1    45.1          133.4
# 29         2gen  2015       169.0    47.1          135.4
# 30         2gen  2016       172.7    49.3          136.5
# 31         2gen  2017       174.8    50.8          166.9
# 32         2gen  2018       178.2    53.1          209.7
# 33         2gen  2019       178.4    53.6          220.3
# 34         2gen  2020       183.8    58.7          277.2

# %%
#creating columns for percentages
df['Permission_percent'] = df.Permission * 100 / (df.Permission+df.Partly+df.No_permission)
df['Partly_percent'] = df.Partly * 100 / (df.Permission+df.Partly+df.No_permission)
df['No_permission_percent'] = df.No_permission * 100 / (df.Permission+df.Partly+df.No_permission)

# %%
#writing the code for just selecting where people come from, not their generation
df[(df.Background =='Dutch') | (df.Background =='Western') | (df.Background=='Non-western')]
# Out:
#      Background  Time  Permission  Partly  No_permission  Permission_percent  \
# 0         Dutch  2014      2546.1   620.4         1289.5           57.138689
# 1         Dutch  2015      2572.9   639.2         1278.2           57.299067
# 2         Dutch  2016      2608.4   661.5         1259.5           57.588202
# 3         Dutch  2017      2622.2   676.5         1350.3           56.403528
# 4         Dutch  2018      2646.5   698.6         1459.6           55.081483
# 5         Dutch  2019      2641.7   703.6         1480.9           54.736646
# 6         Dutch  2020      2692.0   762.6         1729.9           51.924004
# 7       Western  2014       205.7    46.7          146.2           51.605620
# 8       Western  2015       208.1    48.0          145.3           51.843548
# 9       Western  2016       211.5    49.6          143.6           52.260934
# 10      Western  2017       213.9    50.6          156.8           50.771422
# 11      Western  2018       217.0    52.0          171.3           49.284579
# 12      Western  2019       218.1    52.4          176.1           48.835647
# 13      Western  2020       226.1    56.6          211.3           45.769231
# 14  Non-western  2014        44.5    19.8          146.6           21.100047
# 15  Non-western  2015        46.9    21.2          150.6           21.444902
# 16  Non-western  2016        49.8    22.7          153.1           22.074468
# 17  Non-western  2017        52.6    23.9          201.2           18.941304
# 18  Non-western  2018        56.2    25.4          269.4           16.011396
# 19  Non-western  2019        57.5    25.9          292.5           15.296621
# 20  Non-western  2020        63.0    29.1          383.8           13.238075
#
#     Partly_percent  No_permission_percent
# 0        13.922801              28.938510
# 1        14.235129              28.465804
# 2        14.604583              27.807215
# 3        14.551516              29.044956
# 4        14.539930              30.378588
# 5        14.578758              30.684597
# 6        14.709229              33.366766
# 7        11.716006              36.678374
# 8        11.958146              36.198306
# 9        12.255992              35.483074
# 10       12.010444              37.218134
# 11       11.810129              38.905292
# 12       11.733094              39.431258
# 13       11.457490              42.773279
# 14        9.388336              69.511617
# 15        9.693644              68.861454
# 16       10.062057              67.863475
# 17        8.606410              72.452287
# 18        7.236467              76.752137
# 19        6.890130              77.813248
# 20        6.114730              80.647195

# %%
#graphing the info
import matplotlib.pyplot as plt
ax = plt.gca()

df[(df.Background =='Dutch') | (df.Background =='Western') | (df.Background=='Non-western')].groupby(by='Background').plot(kind='line',x='Time',y=["Permission_percent", "Partly_percent", "No_permission_percent"],ax=ax)

plt.show()

# %%
#This graph is too messy to understand, so I'm making three percentage graphs
df[(df.Background =='Dutch') | (df.Background =='Western') | (df.Background=='Non-western')].groupby(by='Background').plot(x ='Time', y=["Permission_percent", "Partly_percent", "No_permission_percent"], kind = 'line')
# Out:
# Background
# Dutch          AxesSubplot(0.125,0.125;0.775x0.755)
# Non-western    AxesSubplot(0.125,0.125;0.775x0.755)
# Western        AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#as well as a graphs for just 'No permission'
df[(df.Background =='Dutch') | (df.Background =='Western') | (df.Background=='Non-western')].groupby(by='Background').plot(x ='Time', y="No_permission_percent", kind = 'line')
# Out:
# Background
# Dutch          AxesSubplot(0.125,0.125;0.775x0.755)
# Non-western    AxesSubplot(0.125,0.125;0.775x0.755)
# Western        AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#making the same graphs for 1st and 2nd generation migrants (unknown whether they are western or not
df[(df.Background =='1gen')|(df.Background =='2gen')].groupby(by='Background').plot(x ='Time', y=["Permission_percent", "Partly_percent", "No_permission_percent"], kind = 'line')
# Out:
# Background
# 1gen    AxesSubplot(0.125,0.125;0.775x0.755)
# 2gen    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#making a chart for 'no permission' for all types
ax = plt.gca()

df[(df.Background =='Dutch') | (df.Background =='Western') | (df.Background=='Non-western')].groupby(by='Background').plot(kind='line',x='Time',y='No_permission_percent',ax=ax)

plt.show()
